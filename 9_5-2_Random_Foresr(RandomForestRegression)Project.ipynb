# %% [markdown]
# # Day 45

# %% [markdown]
# ## Random Forest Regressor Project
#
#
# Link - https://raw.githubusercontent.com/sahilrahman12/Price_prediction_of_used_Cars_-Predictive_Analysis-/master/cardekho_data.csv
#
#
# - Do this same project on Linear Regression, Decision Tree and then on Random Forest Regressor
# - and find out the accuracy of the model
# - do in one file like collective work.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("https://raw.githubusercontent.com/sahilrahman12/Price_prediction_of_used_Cars_-Predictive_Analysis-/master/cardekho_data.csv")

# %% [markdown]
# ### Data Analysis
# * EDA, DE, DM, DC, DV

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print("Fuel Type",df.Fuel_Type.unique())
print("Seller Type", df.Seller_Type.unique())
print('Transmission',df.Transmission.unique())
print("Owner Type", df.Owner.unique())
# Out:
# Fuel Type ['Petrol' 'Diesel' 'CNG']
# Seller Type ['Dealer' 'Individual']
# Transmission ['Manual' 'Automatic']
# Owner Type [0 1 3]

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# We want to check how old the carr is from todays date/Year
df['current_year'] = 2023
df['no._of_year'] = df['current_year'] - df.Year

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  current_year  no._of_year
# 0      Dealer       Manual      0          2023            9
# 1      Dealer       Manual      0          2023           10
# 2      Dealer       Manual      0          2023            6
# 3      Dealer       Manual      0          2023           12
# 4      Dealer       Manual      0          2023            9

# %%
# Droping the columns as we don't required it for further process
df.drop(columns=['Car_Name', 'Year','current_year'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no._of_year
# 0       Manual      0            9
# 1       Manual      0           10
# 2       Manual      0            6
# 3       Manual      0           12
# 4       Manual      0            9

# %%
# Changig the Categorical to numerical using dummies or OneHotEncoding
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no._of_year  \
# 0           3.35           5.59       27000      0            9
# 1           4.75           9.54       43000      0           10
# 2           7.25           9.85        6900      0            6
# 3           2.85           4.15        5200      0           12
# 4           4.60           6.87       42450      0            9
#
#    Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0              0                 0                 1                   1
# 1              0                 1                 0                   1
# 2              0                 0                 1                   1
# 3              0                 0                 1                   1
# 4              0                 1                 0                   1
#
#    Seller_Type_Individual  Transmission_Automatic  Transmission_Manual
# ...

# %%
# We are droping few columns as if it there or not the meaning will be the same.
df.drop(columns=['Fuel_Type_CNG','Seller_Type_Dealer','Transmission_Automatic'],axis = 1, inplace=True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no._of_year  \
# 0           3.35           5.59       27000      0            9
# 1           4.75           9.54       43000      0           10
# 2           7.25           9.85        6900      0            6
# 3           2.85           4.15        5200      0           12
# 4           4.60           6.87       42450      0            9
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
df.shape
# Out:
# (301, 9)

# %%
df.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no._of_year                 -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         no._of_year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price             -0.236141          0.552339         -0.540571
# Present_Price              0.047584          0.473306         -0.465244
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, cmap = "coolwarm_r");
plt.show()

# %%
sns.pairplot(df);
plt.show()

# %% [markdown]
# ### Assigning the Features and Targets:

# %%
# X = np.array(df.iloc[:,1:])
# y = np.array(df.iloc[:,0])

X = df.iloc[:,1:]
y = df.iloc[:,0]

# %%
X
# Out:
#      Present_Price  Kms_Driven  Owner  no._of_year  Fuel_Type_Diesel  \
# 0             5.59       27000      0            9                 0
# 1             9.54       43000      0           10                 1
# 2             9.85        6900      0            6                 0
# 3             4.15        5200      0           12                 0
# 4             6.87       42450      0            9                 1
# ..             ...         ...    ...          ...               ...
# 296          11.60       33988      0            7                 1
# 297           5.90       60000      0            8                 0
# 298          11.00       87934      0           14                 0
# 299          12.50        9000      0            6                 1
# 300           5.90        5464      0            7                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                   1                       0                    1
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# ### Feature Selection (Feature Importance)

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model = ExtraTreesRegressor()
feat_imp = model.fit(X,y)

# %%
feat_imp.feature_importances_
# Out:
# array([0.38016061, 0.0423096 , 0.0009616 , 0.07367779, 0.23160584,
#        0.00761998, 0.13542483, 0.12823975])

# %%
imp = pd.Series(feat_imp.feature_importances_, index=X.columns)
imp.nlargest(5).plot(kind='barh');
plt.show()

# %% [markdown]
# In above graph it shows that the mejor of the impact is due to present_price Feature.

# %% [markdown]
# ### Spliting the Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (240, 8)

# %%
X_test.shape
# Out:
# (61, 8)

# %% [markdown]
# ### Model Selection

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %% [markdown]
# ### Hyper Parameter Tuning
# - For hyper parameter tuning refer to the Sklearn website with the Model name.

# %%
n_estimators = [int (i) for i in np.linspace(start = 100,stop = 1200, num = 12)]

max_features = ['auto', 'sqrt']

max_depth = [int (i) for i in np.linspace(start = 5, stop = 30, num = 6)]

min_samples_split = [2, 5, 10, 10, 100]

min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,
               "max_features": max_features,
               'max_features': max_features,
               'max_depth': max_depth,
               "min_samples_split": min_samples_split,
               'min_samples_leaf': min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 10, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
hyp_model = RandomizedSearchCV(estimator=model,
                               param_distributions= random_grid,
                               scoring = 'neg_mean_squared_error',
                               cv = 5,
                               verbose= 2,
                               random_state= 42,
                               n_jobs= 1)

# %% [markdown]
# ### Training the model

# %%
hyp_model.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=5, n_estimators=900; total time=   1.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.9s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=2, min_samples_split=10, n_estimators=1100; total time=   1.8s
# ...

# %%
hyp_model.best_params_
# Out:
# {'n_estimators': 700,
#  'min_samples_split': 10,
#  'min_samples_leaf': 1,
#  'max_features': 'auto',
#  'max_depth': 20}

# %% [markdown]
# ### Prediction

# %%
y_pred = hyp_model.predict(X_test)

# %%
plt.scatter(y_test, y_pred);
plt.show()

# %%
# Creating Final Dataframe

finaldf = pd.DataFrame({"Actual": y_test, "Predicted":y_pred})
finaldf
# Out:
#      Actual  Predicted
# 223    8.25   6.961560
# 150    0.50   0.511015
# 226    5.25   4.887426
# 296    9.50   8.633039
# 52    18.00  13.981973
# ..      ...        ...
# 137    0.65   0.437882
# 227    2.55   2.646454
# 26     4.15   3.542006
# 106    1.35   2.609436
# 92     3.51   4.287178
#
# [61 rows x 2 columns]

# %%
finaldf.corr()
# Out:
#              Actual  Predicted
# Actual     1.000000   0.979864
# Predicted  0.979864   1.000000

# %%
sns.heatmap(finaldf.corr(), annot=True, cmap = "PuRd");
plt.show()

# %% [markdown]
# ### Performance / Accuracy

# %%
r2_score(y_test, y_pred)
# Out:
# 0.947812622852356
