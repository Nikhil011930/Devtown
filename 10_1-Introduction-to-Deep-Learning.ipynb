# %% [markdown]
# # Day 56

# %% [markdown]
# | AI | ML | DL |
# |----|----|-----|
# | Artificial Intelligence| Machine Learning | Deep Learning|
# ||CPU|GPU, TPU, Kaggle Kernal|
# |1956 --> John McCarthy|1959 --> Arthur Samule|2000 --> Igor Aizenberg|
# | It is a program that can sense, reason, act and adept like human or try to minic human behaviour| It is an algorithem that tries to improve the performance as they are getting experience with more data over data.| It is an algorithem that is inspired by the structure and functioning of human brain.|
# | Threshould  Temperature| Training Time: Less, Testing Time: More| Training Time: More, Testing Time: Less|

# %% [markdown]
# > ![image.png](attachment:image.png)
# >
# > **Big Data**
# > - Hive
# > - Apache Spark
# > - Data Bricks
# > - PySpark
# > - Hadoop
# > - HDFS System

# %% [markdown]
# > **Why we have to use DL?**
# > 1. Huge ammount of data.
# > 2. Complex Problems.
# > 3. Feature Extractions.
# > 4. Accuracy is more.
# >
# > |Curse of Dimensionality|
# > |--|
# >
# > **Where DL is being used?**
# > 1. Medical Fields.
# > 2. Robotics
# > 3. Self Driving Car
# > 4. Translation
# >
# > **Libraries**
# > - Tensorflow
# > - Keras
# > - NLTK
# > - OpenCV
# >
# >
