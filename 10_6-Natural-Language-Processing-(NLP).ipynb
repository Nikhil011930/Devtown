# %% [markdown]
# # Day 61

# %% [markdown]
# - This is a field of AI that gives the machine the abality to read, understand and to derive meaning and insights from human languages.
# - Sight, Smell, Hearing,Feeling,Tast --> Sences

# %% [markdown]
# > 1. **Bag of Words:** It will count all the words in a piece of text.
# >  - It will give the occurance of words.
#
# | Example | ![image.png](attachment:image.png)|
# |---|---|
#
#
# > - Stop words
# > - Rescale the frequency of words.

# %% [markdown]
# > 2. **Tokenization:** It will going to breakdown the sentences into words.
#
# | Example | ![image.png](attachment:image.png) |
# |---|---|
#
# > 3. **Removing the Stop Words:** Removing the stop words or more frequent appering words.
# >
# > 4. **Stemming:** To slice the end or the beginning of the words with the intention/motive of removing affixes.
# > - Affiex or Suffixes.
# >
# | Example | ![image.png](attachment:image-2.png) |
# |---|---|
#
# > 5. **Lemmatization:** It will going to take that word and it will going to reduce that in a base form.
# > - Basically it is going to change the past tense/word into a present format.
#
# > |Example | Went---> go | best --> good| Caring --> Care (L), Caring --> Car (S)|Running, Runs, Ran --> Run|
# > |--|--|--|--|--|
