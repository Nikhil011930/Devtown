# %% [markdown]
# # Day 53

# %% [markdown]
# > ### Unsupervised Learning
# > 1. Clustering
# > 2. Association
# >>- It is used for Market Basket Analysis and also for Recommendation System

# %% [markdown]
# > # 1.Apriori
# >> ![image.png](attachment:image.png) ![image.png](attachment:image-2.png)
# >>> ### **Working of Apriori Algoritheme**
# >>> Termonology: 1.Support 2.Confidence. This two will going to find out the relationship of two or more item is making the strong bond with each other.
# >>>
# >>>> **Support** (i) = No. of transactions that contains I / Total no. of transaction
# >>>
# >>>> **Confidence**(X -> y) = No. of transactions that containing X and Y / Total no. of transaction that contains X
# >>>
# >>> ![image.png](attachment:image-3.png)![image.png](attachment:image-4.png) ![image.png](attachment:image-5.png)
