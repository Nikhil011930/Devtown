# %% [markdown]
# # Day 32

# %% [markdown]
# ## Project 4 : Technology Lookup Data CLeaning (JSON)
#
# Dataset (JSON) :
# 1. "https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json"
#
# 2. "https://gitlab.msu.edu/popeoliv/wappalyzer/-/raw/v6.5.25/src/technologies.json"
#
# 3. Little bit complicated.

# %% [markdown]
# - Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
tech = pd.read_json("https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json")
cats = pd.read_json ("https://gitlab.msu.edu/popeoliv/wappalyzer/-/raw/v6.5.25/src/technologies.json")

# %%
data_tech = tech.copy()
data_cats = cats.copy()

# %% [markdown]
# 1. Manuplate the DataFrame in a such as way that the columns becomes the row and vice-versa.

# %%
data_tech = data_tech.transpose()

# %%
data_tech.head()
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
# @sulu/web    [59]                                                NaN
# A-Frame      [25]                                                NaN
# A8.net       [71]          A8.net is an affiliate marketing network.
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
# @sulu/web                                                NaN
# A-Frame                                                  NaN
# A8.net                                                   NaN
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# ...

# %%
data_tech.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1511 entries, 1C-Bitrix to xtCommerce
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cats         1511 non-null   object
#  1   description  776 non-null    object
#  2   headers      320 non-null    object
#  3   html         428 non-null    object
#  4   icon         1474 non-null   object
#  5   implies      482 non-null    object
#  6   scripts      679 non-null    object
#  7   website      1511 non-null   object
#  8   cookies      146 non-null    object
#  9   js           600 non-null    object
#  10  dom          60 non-null     object
#  11  pricing      213 non-null    object
#  12  saas         204 non-null    object
#  13  meta         272 non-null    object
#  14  cpe          195 non-null    object
#  15  certIssuer   5 non-null      object
#  16  url          51 non-null     object
#  17  oss          31 non-null     object
# ...

# %%
data_tech.shape
# Out:
# (1511, 21)

# %%
data_tech.columns
# Out:
# Index(['cats', 'description', 'headers', 'html', 'icon', 'implies', 'scripts',
#        'website', 'cookies', 'js', 'dom', 'pricing', 'saas', 'meta', 'cpe',
#        'certIssuer', 'url', 'oss', 'dns', 'excludes', 'css'],
#       dtype='object')

# %%
data_cats.head()
# Out:
#           $schema                                    categories technologies
# 1  ../schema.json                {'name': 'CMS', 'priority': 1}          NaN
# 2  ../schema.json     {'name': 'Message boards', 'priority': 1}          NaN
# 3  ../schema.json  {'name': 'Database managers', 'priority': 2}          NaN
# 4  ../schema.json      {'name': 'Documentation', 'priority': 2}          NaN
# 5  ../schema.json            {'name': 'Widgets', 'priority': 9}          NaN

# %%
data_cats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1603 entries, 1 to xtCommerce
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   $schema       1603 non-null   object
#  1   categories    72 non-null     object
#  2   technologies  1531 non-null   object
# dtypes: object(3)
# memory usage: 50.1+ KB

# %%
tec = data_tech.copy()
cat = data_cats.copy()

# %%
cat.categories
# Out:
# 1                           {'name': 'CMS', 'priority': 1}
# 2                {'name': 'Message boards', 'priority': 1}
# 3             {'name': 'Database managers', 'priority': 2}
# 4                 {'name': 'Documentation', 'priority': 2}
# 5                       {'name': 'Widgets', 'priority': 9}
#                                   ...
# wisyCMS                                                NaN
# wpBakery                                               NaN
# wpCache                                                NaN
# xCharts                                                NaN
# xtCommerce                                             NaN
# Name: categories, Length: 1603, dtype: object

# %%
for i in tec.cats:
    for j in range(len(i)):
        i[j] = cat.categories.iloc[(i[j]-1)]["name"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 for i in tec.cats:
#       2       for j in range(len(i)):
# ----> 3         i[j] = cat.categories.iloc[(i[j]-1)]["name"]
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
for i in tec.cats:
  print (i)
# Out:
# ['CMS', 'Ecommerce']
# ['CMS', 'Ecommerce']
# ['PaaS']
# ['JavaScript graphics']
# ['A/B Testing']
# [74]
# [10]
# [10]
# [12]
# [1, 5]
# [22]
# [59]
# [10]
# [10]
# [6]
# [71]
# [70]
# [10]
# [6]
# [71]
# [68]
# [6, 72]
# [62]
# [32]
# [36]
# [36]
# [36]
# [36]
# [68]
# [36]
# [5, 10]
# [5]
# [5]
# [3]
# [36]
# [10]
# [18]
# [42]
# [1]
# [10]
# [42]
# [20]
# [4]
# [32, 74]
# [18]
# [10]
# [36]
# [36]
# [41]
# [36]
# [11]
# [71, 36]
# [71]
# [6]
# [6]
# [41]
# [10]
# [32]
# [52]
# [31]
# [19]
# [32, 10]
# [31]
# [16]
# [16]
# [10, 47]
# [55]
# [18, 22]
# [29]
# [54]
# [22]
# [12]
# [12]
# [20]
# [65]
# [71]
# [31]
# [22]
# [63]
# [65]
# [41]
# [19]
# [75]
# [62]
# [6]
# [18, 22]
# [41]
# [1]
# [41]
# [1]
# [10]
# [10]
# [36]
# [12]
# [66]
# [18]
# [12]
# [12]
# [22]
# [8]
# [22]
# [22]
# [18]
# [51]
# [4]
# [41]
# [59]
# [1]
# [10]
# [36]
# [62]
# [41]
# [69]
# [72]
# [6]
# [1]
# [35]
# [47]
# [22]
# [31]
# [1, 20, 27]
# [14]
# [29]
# [47]
# [8]
# [47]
# [13]
# [13, 47]
# [13, 62]
# ...

# %%
tec.description.isna().sum()
# Out:
# 735

# %%
tec.headers
# Out:
# 1C-Bitrix     {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                               {'X-Powered-By': '3DCART'}
# @sulu/web                                                   NaN
# A-Frame                                                     NaN
# A8.net                                                      NaN
#                                     ...
# wisyCMS                                                     NaN
# wpBakery                                                    NaN
# wpCache       {'X-Powered-By': 'wpCache(?:/([\d.]+))?\;versi...
# xCharts                                                     NaN
# xtCommerce                                                  NaN
# Name: headers, Length: 1511, dtype: object

# %%
tec.headers.notnull().sum()
# Out:
# 320

# %%
tec.headers.isnull().sum()
# Out:
# 1191

# %%
tec.headers[0]
# Out:
# {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bitrix Site Manager'}

# %%
arr = []
for i in range (len(tec.headers)):
  if not pd.isnull(tec.headers[i]) :
    arr.extend(list(tec.headers[i].keys()))

# %%
arr = set(arr)

# %%
len(arr)
# Out:
# 185

# %%
arr
# Out:
# {'AR-PoweredBy',
#  'Access-Control-Allow-Headers',
#  'Arastta',
#  'CMS-Version',
#  'COMMERCE-SERVER-SOFTWARE',
#  'Composed-By',
#  'Content-Type',
#  'Cookie',
#  'DNNOutputCache',
#  'Derak-Umbrage',
#  'Expires',
#  'Fastly-Debug-Digest',
#  'IBM-Web2-Location',
#  'Itx-Generated-Timestamp',
#  'Liferay-Portal',
#  'Link',
#  'MicrosoftSharePointTeamServices',
#  'OracleCommerceCloud-Version',
#  'Powered-By',
#  'SPRequestGuid',
#  'Server',
#  'Servlet-engine',
#  'Set-Cookie',
#  'SharePointHealthScore',
#  'Vary',
#  'Via',
#  'WP-Super-Cache',
#  'WebDevSrc',
#  'Weglot-Translated',
#  'X-AH-Environment',
#  'X-ATG-Version',
#  'X-Advertising-By',
#  'X-Akamai-Transformed',
#  'X-Akaunting',
#  'X-Amz-Cf-Id',
#  'X-Application-Context',
#  'X-Arastta',
#  'X-AspNet-Version',
#  'X-B3-Flags',
#  'X-B3-ParentSpanId',
#  'X-B3-Sampled',
#  'X-B3-SpanId',
#  'X-B3-TraceId',
#  'X-Backdrop-Cache',
#  'X-Backside-Transport',
#  'X-CDN',
#  'X-CDN-Forward',
#  'X-CF1',
# ...

# %%
tec
# Out:
#                              cats  \
# 1C-Bitrix        [CMS, Ecommerce]
# 3dCart           [CMS, Ecommerce]
# @sulu/web                  [PaaS]
# A-Frame     [JavaScript graphics]
# A8.net              [A/B Testing]
# ...                           ...
# wisyCMS                       [1]
# wpBakery                     [51]
# wpCache                      [23]
# xCharts                      [25]
# xtCommerce                    [6]
#
#                                                   description  \
# 1C-Bitrix   1C-Bitrix is a system of web project managemen...
# 3dCart                                                    NaN
# @sulu/web                                                 NaN
# A-Frame                                                   NaN
# A8.net              A8.net is an affiliate marketing network.
# ...                                                       ...
# wisyCMS                                                   NaN
# ...
