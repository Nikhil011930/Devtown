# %% [markdown]
# # Day 60

# %% [markdown]
# ## Recurrent Neural NEtwork (RNN)
#
# - RNN follows the sequential pattern:
#   - NLP
#   - Sentimenal Analysis (Review of any types)
#     - Review of any types: Positive or Negative Review
# - For activation of the neural network / RNN we will use **Tanh** function.
#
#
# |![image.png](attachment:image.png)|
# |--|
#
# |--Input--> |--Hidden layer1---|--Hidden layer2---|--Hidden layer3---|--Output--|
# |------|---|----|---|----|
# |Input|(Weight,Bias) W1,B1|W2,B2|W3,B3||
# ||Activation ||||
# ||As the weight and bias of each of the hidden layers are difeerent so each of the hidden layer will behave independently|To make those hidden layer/Neuron act as dependent we have must have the constant values, in order to combine those hidden values try to make the weight and the bias same|||
# Example
# |Input (Hello) but only providing them the 4 words Hell|RNN (It will ask to predict the last word of Hell)|Output|
#
# |![image.png](attachment:image-2.png)|
# |--|

# %% [markdown]
# - Pros.: At every times it always stores the information at each states.
#   - RNN can also be used as CNN
#   - CNN is mostly is used for Medias
#   - RNN is mostly used for when we are using the textual part.
#   - Text summarizer -->1. Extractive 2.Abstractive
# - Cons. : Training the RNN is very difficult task because it goes on an on, more training is required. As it follows the sequence sequence is very important.
#   - RNN do stores all the informations but it can not process as very long seeker, the seeker should be very short.
#
#
# |After taking the input the model will convert that input into OneHotencoding Part.| ![image.png](attachment:image.png) |
# |---|--|
